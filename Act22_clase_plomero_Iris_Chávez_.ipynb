# %% [markdown]
# <a href="https://colab.research.google.com/github/a25308051280032-boop/Act21-clase-plomero-Iris-Ch-vez-0032/blob/main/Act22_clase_plomero_Iris_Ch%C3%A1vez_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Iris Chavez NL = 11 Fecha 23/Abr/2026
# #### Clase plomero
# ![](https://private-user-images.githubusercontent.com/260754563/583508264-f024df59-7d0f-4a0b-9f8f-e07a55f6eca7.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmF3LmdpdGh1YnVzZXJjb250ZW50LmNvbSIsImtleSI6ImtleTUiLCJleHAiOjE3NzcwNDk0OTYsIm5iZiI6MTc3NzA0OTE5NiwicGF0aCI6Ii8yNjA3NTQ1NjMvNTgzNTA4MjY0LWYwMjRkZjU5LTdkMGYtNGEwYi05ZjhmLWUwN2E1NWY2ZWNhNy5wbmc_....PqdsNqNfy6-aYlQuBYEMQqrB66YOReyUCPUbrp5fn60)

# %%
class Plomero:
    def __init__(self, licencia, herramientas, experiencia):
        # Inicialización de los atributos
        self.licencia = licencia
        self.herramientas = herramientas
        self.experiencia = experiencia

    def instalacion_de_tuberias(self):
        return f"Realizando instalación profesional con licencia {self.licencia}."

    def mantenimiento_de_tuberias(self):
        return f"Ejecutando mantenimiento preventivo usando mis {self.herramientas}."

    def reportar_estado(self):
        return f"Plomero con {self.experiencia} años de experiencia activo."

# Creación de los objetos (instancias)
fontanero1 = Plomero("LP-1020", "llave inglesa y soplete", 5)
fontanero2 = Plomero("LP-8845", "cortadora de tubos y sellador", 12)

# Uso de las funciones y visualización de datos
print("--- Datos de Fontanero 1 ---")
print(f"Licencia: {fontanero1.licencia}")
print(fontanero1.instalacion_de_tuberias())
print(fontanero1.reportar_estado())

print("\n--- Datos de Fontanero 2 ---")
print(f"Licencia: {fontanero2.licencia}")
print(fontanero2.mantenimiento_de_tuberias())
print(fontanero2.reportar_estado())
print("---------------------------------------------------")
print("Programa realizado por Iris Chavez NL = 11")
# Out:
# --- Datos de Fontanero 1 ---
# Licencia: LP-1020
# Realizando instalación profesional con licencia LP-1020.
# Plomero con 5 años de experiencia activo.
#
# --- Datos de Fontanero 2 ---
# Licencia: LP-8845
# Ejecutando mantenimiento preventivo usando mis cortadora de tubos y sellador.
# Plomero con 12 años de experiencia activo.
# ---------------------------------------------------
# Programa realizado por Iris Chavez NL = 11

# %% [markdown]
# ![image.png](https://private-user-images.githubusercontent.com/260754563/583509891-710880bb-0c63-4037-90f3-b860eb3b84ae.png?jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmF3LmdpdGh1YnVzZXJjb250ZW50LmNvbSIsImtleSI6ImtleTUiLCJleHAiOjE3NzcwNDk4OTIsIm5iZiI6MTc3NzA0OTU5MiwicGF0aCI6Ii8yNjA3NTQ1NjMvNTgzNTA5ODkxLTcxMDg4MGJiLTBjNjMtNDAzNy05MGYzLWI4NjBlYjNiODRhZS5wbmc_....dJUM2Tlkx6aKCgBOA7Pb3ju6dYjVavZX7f1rdFlwORg)
